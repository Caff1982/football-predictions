# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import os
import random

# Set random seed for reproducibility
np.random.seed(42)
random.seed(42)
os.environ['PYTHONHASHSEED'] = str(42)

from keras import backend as K
config = tf.ConfigProto(intra_op_parallelism_threads=1,inter_op_parallelism_threads=1)
tf.set_random_seed(42)
sess = tf.Session(config=config)
K.set_session(sess)

import keras
from keras.layers import Dense, Dropout, BatchNormalization
from keras.callbacks import EarlyStopping

from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.preprocessing import StandardScaler



DATA_PATH = 'data/'
# Out:
# /home/stephen/Projects/betting_model/env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/stephen/Projects/betting_model/env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/stephen/Projects/betting_model/env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/stephen/Projects/betting_model/env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/stephen/Projects/betting_model/env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/stephen/Projects/betting_model/env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/stephen/Projects/betting_model/env/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/stephen/Projects/betting_model/env/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/stephen/Projects/betting_model/env/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/stephen/Projects/betting_model/env/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/stephen/Projects/betting_model/env/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/stephen/Projects/betting_model/env/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.

# %%
league_data = pd.read_csv('data/league_data.csv')
league_data.drop(['Unnamed: 0', 'Date', 'HomeTeam', 'AwayTeam', 
                 'HTGS', 'ATGS', 'HTGC', 'ATGC', 'HM1', 'HM2', 'HM3',
                 'HM4', 'HM5', 'AM1', 'AM2', 'AM3', 'AM4', 'AM5', 'HTFormPts',
                 'ATFormPts', 'MW', 'HTFormPtsStr', 'ATFormPtsStr'], 1, inplace=True)
league_data.columns
# Out:
# Index(['season', 'FTR', 'HTP', 'ATP', 'B365H', 'B365D', 'B365A', 'gameId',
#        'HTGD', 'ATGD', 'DiffPts', 'DiffFormPts', 'DiffLP'],
#       dtype='object')

# %%
EMA_data = pd.read_csv('data/EMA_data.csv')
EMA_data.drop(['Unnamed: 0', 'f_DateHome', 'f_seasonHome', 'HomeTeam',
               'homeGame_x', 'f_yellowsAgainstAway', 'f_yellowsForAway',
               'f_halfTimeGoalsAgainstHome', 'f_halfTimeGoalsForHome','f_halfTimeGoalsAgainstAway', 'f_halfTimeGoalsForAway',
               'f_yellowsAgainstHome', 'f_yellowsForHome', 'f_DateAway', 'f_seasonAway', 
               'AwayTeam', 'homeGame_y'], 1, inplace=True)
EMA_data.columns
# Out:
# Index(['gameId', 'f_cornersAgainstHome', 'f_cornersForHome',
#        'f_freesAgainstHome', 'f_freesForHome', 'f_goalsAgainstHome',
#        'f_goalsForHome', 'f_redsAgainstHome', 'f_redsForHome',
#        'f_shotsAgainstHome', 'f_shotsForHome', 'f_shotsOnTargetAgainstHome',
#        'f_shotsOnTargetForHome', 'f_cornersAgainstAway', 'f_cornersForAway',
#        'f_freesAgainstAway', 'f_freesForAway', 'f_goalsAgainstAway',
#        'f_goalsForAway', 'f_redsAgainstAway', 'f_redsForAway',
#        'f_shotsAgainstAway', 'f_shotsForAway', 'f_shotsOnTargetAgainstAway',
#        'f_shotsOnTargetForAway'],
#       dtype='object')

# %%
df = pd.merge(EMA_data, league_data, left_on='gameId', right_index=True)

# %%
# df['season'].apply(str)

# %%
df.head()
# Out:
#    gameId  gameId_x  f_cornersAgainstHome  f_cornersForHome  \
# 0      22        22               8.53000          3.000000
# 1      23        23               3.62605          3.359819
# 2      24        24               6.49000          8.060000
# 3      25        25               5.96000          1.490000
# 4      26        26               5.45000         10.550000
#
#    f_freesAgainstHome  f_freesForHome  f_goalsAgainstHome  f_goalsForHome  \
# 0           12.510000        9.490000            1.000000        1.020000
# 1           13.893348       12.291828            0.320091        1.680443
# 2           14.920000       12.020000            2.470000        1.000000
# 3            7.020000       11.470000            1.530000        0.980000
# 4           14.530000       13.510000            1.510000        0.000000
#
#    f_redsAgainstHome  f_redsForHome  ...       ATP  B365H  B365D  B365A  \
# 0                0.0            0.0  ...  0.333333   1.44   4.00   7.50
# 1                0.0            0.0  ...  1.333333   2.20   3.25   3.20
# 2                0.0            0.0  ...  1.333333   3.10   3.20   2.25
# 3                0.0            0.0  ...  2.000000   2.62   3.10   3.10
# 4                0.0            0.0  ...  0.666667   4.50   3.25   1.83
#
#    gameId_y      HTGD      ATGD   DiffPts  DiffFormPts  DiffLP
# 0        23  0.666667 -1.666667 -0.333333    -0.333333     -13
# 1        24  1.333333 -1.000000 -0.333333    -0.333333      -1
# 2        25  0.000000  0.333333  0.000000     0.000000       6
# 3        26  0.666667  0.333333 -0.666667    -0.666667       1
# 4        27  0.666667 -0.333333  1.333333     1.333333      13
#
# [5 rows x 39 columns]

# %% [markdown]
# # Prepare and split the data
#
# Now that we have loaded our data into a dataframe we will clean the data for our Keras model. Because the model only takes numeric input we will change our labels from strings to integers and use categorical cross-entropy as our loss function. We will also scale our data using sklearn StandardScaler.
#
# First we will seperate the labels from the rest of our data.

# %%
training_data = df.loc[df['season'] != 1920].reset_index(drop=True)
testing_data = df.loc[df['season'] == 1920].reset_index(drop=True)

X = training_data.drop(['gameId', 'gameId_x', 'gameId_y', 'FTR', 
           'season', 'gameId_y', ], 1)
Y = training_data['FTR']

X_test = testing_data.drop(['gameId', 'gameId_x', 'gameId_y', 'FTR', 
           'season', 'gameId_y', ], 1)
y_test = testing_data['FTR']

# Use 'season' columns to create training batches
seasons = training_data['season']

# %%
def transform_results(results):
    transformed = []
    for i in range(len(results)):
        if results[i] == 'H':
            transformed.append(0)
        elif results[i] == 'A':
            transformed.append(2)
        else:
            transformed.append(1)
    return np.array(transformed)
            
Y = transform_results(Y)
y_test = transform_results(y_test)

# %%
scaler = StandardScaler()

X = scaler.fit_transform(X)
X_test = scaler.fit_transform(X_test)

# %%
print('Number of matches in training data:', X.shape[0])
print('Number of matches in test data:', X_test.shape[0])
print('Number of features:', X.shape[1])
# Out:
# Number of matches in training data: 4504
# Number of matches in test data: 118
# Number of features: 34

# %%
# Split our data. We are using the most recent season for validation
X_train = X[:-380]
y_train = Y[:-380]
X_val = X[-380:]
y_val = Y[-380:]

# %% [markdown]
# # Build the model
#
# Now we have cleaned the data we can now create our model and train it.

# %%
input_dim = X_train.shape[1]

activation_func = 'relu'
kernel_init = 'glorot_normal'
dropout_rate = 0.4
learning_rate = 0.002
batch_size = 16

model = keras.Sequential([
    Dense(50, input_shape=(input_dim,), activation=activation_func),
    Dropout(0.3),
    Dense(16),
    Dropout(0.2),
    Dense(3, activation='softmax')
])

# %%
es = EarlyStopping(monitor='loss', patience=3, verbose=1)

# %%
from keras.optimizers import Adam, SGD

opt = Adam(lr=learning_rate, beta_1=0.9, beta_2=0.995, epsilon=1e-08, decay=0.0)
# opt = SGD(momentum=0.0, learning_rate=0.01, nesterov=False)

# %%
model.compile(optimizer=opt, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.fit(X_train, y_train, batch_size=batch_size, 
              callbacks=[es], epochs=500, verbose=0)
# Out:
# WARNING:tensorflow:From /home/stephen/Projects/betting_model/env/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Epoch 00021: early stopping

# %%
_, train_acc = model.evaluate(X_train, y_train)
_, val_acc = model.evaluate(X_val, y_val)
print('Training accuracy:', train_acc)
print('Validation accuracy:', val_acc)
# Out:
# 4124/4124 [==============================] - 0s 17us/step
# 380/380 [==============================] - 0s 22us/step
# Training accuracy: 0.6355479955673218
# Validation accuracy: 0.6526315808296204

# %% [markdown]
# We are getting around 63% on training and 64% on validation. This is good as is above the bookies accuracy. Because our validation data is so small we will also look at our training and validation across all the seasons to see if it is consistant.

# %%
# Saving best model
# model.save('17Nov19.h5')

# %%
# idx = 0
# train_results = []
# val_results = []

# for season_len in seasons.value_counts():
#     X_train = np.concatenate((X[:idx], X[idx+season_len:]))
#     y_train = np.concatenate((Y[:idx], Y[idx+season_len:]))
#     X_val = X[idx:idx+season_len]
#     y_val = Y[idx:idx+season_len]
    
#     model = dnn_model
#     model.compile(optimizer=opt, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
#     model.fit(X_train, y_train, batch_size=batch_size, 
#                     callbacks=[es], epochs=500, verbose=0)
    
#     _, train_acc = model.evaluate(X_train, y_train)
#     _, val_acc = model.evaluate(X_val, y_val)
#     print('Training accuracy:', train_acc)
#     print('Validation accuracy:', val_acc)
    
#     train_results.append(train_acc)
#     val_results.append(val_acc)
#     idx +=season_len

# %%
# print(f'Average training accuracy :{sum(train_results)/len(train_results)}')
# print(f'Min accuracy :{min(train_results)}')
# print(f'Max accuracy :{max(train_results)}')
# print(f'Standard Deviation :{np.std(train_results)}')

# %%
# print(f'Average validation accuracy :{sum(val_results)/len(val_results)}')
# print(f'Min accuracy :{min(val_results)}')
# print(f'Max accuracy :{max(val_results)}')
# print(f'Standard Deviation :{np.std(val_results)}')

# %% [markdown]
# Let's now check our accuracy on the test set and see how accurate this is. We can then look at creating a betting strategy and see if the model would be profitable.

# %%
_, test_acc = model.evaluate(X_test, y_test)
print('Test accuracy:', test_acc)
# Out:
# 118/118 [==============================] - 0s 21us/step
# Test accuracy: 0.6525423526763916

# %%
y_preds = model.predict(X_test)

# %%
# Save predictions 
np.save('y_preds.npy', y_preds)

# %% [markdown]
# # Create a betting strategy
#
# Now that we have an accurate model let's see if we can make it as profitable as possible.

# %%
funds = 100
wager = 10
favourites = 0
no_bets = 0
min_diff = 0.03

for i in range(len(X_test)):
    prediction = np.argmax(y_preds[i])
    print('\nPrediction', prediction)
    print('Actual', y_test[i])
    print('Favourite', np.argmin([testing_data['B365H'][i], testing_data['B365D'][i], 
                                  testing_data['B365A'][i]]))
    print('Prediction proba', y_preds[i])
    print('Home, Draw and Away odds', testing_data['B365H'][i],       
          testing_data['B365D'][i], testing_data['B365A'][i])
    
        

    if prediction == 0:
        odds_diff = y_preds[i][prediction] - (1/testing_data['B365H'][i])
        # If odds_diff positive place bet
        if odds_diff > min_diff:
            if  prediction == y_test[i]:
                funds += (wager * testing_data['B365H'][i]) - wager
            else:
                funds -= wager
        else:
            no_bets +=1
    elif prediction == 1:     
        odds_diff = y_preds[i][prediction] - (1/testing_data['B365D'][i])
        if odds_diff > min_diff:
            if  prediction == y_test[i]:
                funds +=( wager * testing_data['B365D'][i]) - wager
            else:
                funds -= wager
        else:
            no_bets +=1
    else:
        odds_diff = y_preds[i][prediction] - (1/testing_data['B365A'][i])
        if odds_diff >  min_diff:
            if  prediction == y_test[i]:
                funds += (wager * testing_data['B365A'][i]) - wager
            else:
                funds -= wager
        else:
            no_bets +=1

        
    if prediction == np.argmin([testing_data['B365H'][i], testing_data['B365D'][i], 
                                  testing_data['B365A'][i]]):
        favourites +=1
    
    print('Funds', funds)
    
print(f'Betted on favourite {favourites} times out of {len(X_test)} matches.')
print(f'No bet placed {no_bets} times')
# Out:
# Prediction 0
# Actual 0
# Favourite 0
# Prediction proba [0.5430389  0.25684983 0.20011123]
# Home, Draw and Away odds 1.14 10.0 19.0
# Funds 100
#
# Prediction 2
# Actual 2
# Favourite 2
# Prediction proba [0.08087105 0.22293802 0.69619095]
# Home, Draw and Away odds 12.0 6.5 1.22
# Funds 100
#
# Prediction 0
# Actual 1
# Favourite 0
# Prediction proba [0.37600842 0.30000865 0.32398286]
# Home, Draw and Away odds 1.95 3.6 3.6
# Funds 100
#
# Prediction 0
# Actual 0
# Favourite 0
# Prediction proba [0.57025194 0.30299962 0.12674843]
# Home, Draw and Away odds 2.62 3.2 2.75
# Funds 116.2
#
# Prediction 2
# Actual 1
# Favourite 2
# Prediction proba [0.3167887  0.26941282 0.4137985 ]
# Home, Draw and Away odds 3.0 3.25 2.37
# Funds 116.2
#
# Prediction 0
# Actual 2
# Favourite 0
# Prediction proba [0.37060124 0.29953223 0.3298665 ]
# Home, Draw and Away odds 1.9 3.4 4.0
# Funds 116.2
#
# Prediction 0
# Actual 0
# Favourite 0
# Prediction proba [0.35839924 0.32007053 0.3215302 ]
# Home, Draw and Away odds 1.3 5.25 10.0
# Funds 116.2
#
# Prediction 0
# Actual 1
# Favourite 0
# Prediction proba [0.48460916 0.30301532 0.21237545]
# Home, Draw and Away odds 2.2 3.2 3.4
# Funds 106.2
#
# Prediction 2
# Actual 2
# Favourite 2
# Prediction proba [0.18942496 0.30003595 0.5105391 ]
# Home, Draw and Away odds 4.5 3.75 1.72
# Funds 106.2
#
# Prediction 1
# Actual 0
# Favourite 0
# Prediction proba [0.30165118 0.37525702 0.32309175]
# Home, Draw and Away odds 2.1 3.3 3.5
# Funds 96.2
#
# Prediction 2
# Actual 2
# Favourite 0
# Prediction proba [0.12657061 0.31567636 0.557753  ]
# Home, Draw and Away odds 2.3 3.4 3.1
# Funds 117.2
#
# Prediction 2
# Actual 1
# Favourite 0
# Prediction proba [0.04944978 0.31103012 0.6395201 ]
# Home, Draw and Away odds 2.55 3.25 2.87
# Funds 107.2
#
# Prediction 0
# Actual 0
# Favourite 0
# Prediction proba [0.55952644 0.26867694 0.17179668]
# Home, Draw and Away odds 1.72 3.8 4.75
# Funds 107.2
#
# Prediction 0
# Actual 0
# Favourite 0
# Prediction proba [0.96868193 0.02933331 0.00198482]
# Home, Draw and Away odds 2.25 3.3 3.3
# Funds 119.7
#
# Prediction 1
# Actual 2
# Favourite 2
# Prediction proba [0.27574775 0.4257408  0.29851148]
# Home, Draw and Away odds 6.5 4.75 1.44
# Funds 109.7
#
# Prediction 1
# Actual 1
# Favourite 0
# Prediction proba [0.3474164  0.38933504 0.2632485 ]
# Home, Draw and Away odds 1.36 5.25 8.0
# Funds 152.2
#
# Prediction 0
# Actual 0
# Favourite 0
# Prediction proba [0.6601478  0.26017338 0.07967893]
# Home, Draw and Away odds 2.55 3.1 2.9
# Funds 167.7
#
# Prediction 0
# Actual 1
# Favourite 0
# Prediction proba [0.49812606 0.28042454 0.22144942]
# Home, Draw and Away odds 1.7 3.75 5.0
# Funds 167.7
#
# Prediction 0
# Actual 1
# Favourite 2
# Prediction proba [0.6751959  0.26273352 0.06207064]
# Home, Draw and Away odds 3.3 3.3 2.25
# Funds 157.7
#
# Prediction 0
# Actual 0
# Favourite 2
# Prediction proba [0.73922586 0.23604405 0.02473014]
# Home, Draw and Away odds 3.25 3.5 2.15
# Funds 180.2
#
# Prediction 2
# Actual 2
# Favourite 2
# Prediction proba [0.1289262 0.3180533 0.5530205]
# Home, Draw and Away odds 4.33 3.75 1.8
# Funds 180.2
#
# Prediction 2
# Actual 2
# Favourite 0
# Prediction proba [0.00825548 0.1383032  0.85344136]
# Home, Draw and Away odds 2.4 3.3 3.0
# Funds 200.2
#
# Prediction 2
# Actual 2
# Favourite 0
# Prediction proba [0.09370718 0.2570588  0.649234  ]
# Home, Draw and Away odds 1.33 5.25 9.0
# Funds 280.2
#
# Prediction 2
# Actual 2
# Favourite 2
# Prediction proba [0.06727669 0.25778607 0.6749372 ]
# Home, Draw and Away odds 3.3 3.3 2.25
# Funds 292.7
#
# Prediction 2
# Actual 2
# Favourite 0
# Prediction proba [0.0124319  0.07959805 0.90797   ]
# Home, Draw and Away odds 2.05 3.5 3.5
# Funds 317.7
#
# Prediction 0
# Actual 0
# Favourite 0
# Prediction proba [0.8536844  0.11834539 0.0279702 ]
# Home, Draw and Away odds 1.5 4.6 6.0
# Funds 322.7
#
# Prediction 2
# Actual 2
# Favourite 2
# Prediction proba [0.09149659 0.16896638 0.739537  ]
# Home, Draw and Away odds 15.0 7.5 1.16
# Funds 322.7
#
# Prediction 2
# Actual 2
# Favourite 0
# Prediction proba [0.0649421  0.30431706 0.6307408 ]
# Home, Draw and Away odds 1.2 6.5 14.0
# Funds 452.7
#
# Prediction 0
# Actual 1
# Favourite 0
# Prediction proba [0.5810601  0.3005071  0.11843278]
# Home, Draw and Away odds 1.85 3.4 4.5
# Funds 442.7
#
# Prediction 0
# Actual 1
# Favourite 0
# Prediction proba [0.53003603 0.36014342 0.10982049]
# Home, Draw and Away odds 1.36 4.75 9.0
# Funds 442.7
#
# Prediction 0
# Actual 0
# Favourite 0
# Prediction proba [0.3667171  0.27664664 0.3566363 ]
# Home, Draw and Away odds 2.15 3.3 3.5
# Funds 442.7
#
# Prediction 0
# Actual 0
# Favourite 0
# Prediction proba [0.919388   0.07814609 0.002466  ]
# Home, Draw and Away odds 1.7 4.0 4.75
# Funds 449.7
#
# Prediction 0
# Actual 0
# Favourite 0
# Prediction proba [9.8425508e-01 1.4992897e-02 7.5204257e-04]
# Home, Draw and Away odds 1.08 10.0 26.0
# Funds 450.5
#
# Prediction 2
# Actual 1
# Favourite 0
# Prediction proba [0.2103228  0.33864054 0.45103666]
# Home, Draw and Away odds 2.5 3.25 2.87
# Funds 440.5
#
# Prediction 0
# Actual 0
# Favourite 0
# Prediction proba [0.86544716 0.10526767 0.02928517]
# Home, Draw and Away odds 1.85 3.9 3.9
# Funds 449.0
#
# Prediction 2
# Actual 2
# Favourite 2
# Prediction proba [0.0204282  0.1089488  0.87062305]
# Home, Draw and Away odds 9.5 5.5 1.3
# Funds 452.0
#
# Prediction 0
# Actual 0
# Favourite 0
# Prediction proba [0.45543748 0.326621   0.2179416 ]
# Home, Draw and Away odds 2.2 3.25 3.5
# Funds 452.0
#
# Prediction 2
# Actual 1
# Favourite 0
# Prediction proba [0.2063851  0.38015217 0.41346273]
# Home, Draw and Away odds 2.37 3.6 2.8
# Funds 442.0
#
# Prediction 0
# Actual 0
# Favourite 0
# Prediction proba [0.9202806  0.05417822 0.02554117]
# Home, Draw and Away odds 1.14 8.5 17.0
# Funds 443.4
#
# Prediction 1
# Actual 1
# Favourite 0
# Prediction proba [0.3340296  0.38425654 0.2817138 ]
# Home, Draw and Away odds 2.15 3.3 3.5
# Funds 466.4
#
# Prediction 0
# Actual 0
# Favourite 0
# Prediction proba [0.49176314 0.23604068 0.27219614]
# Home, Draw and Away odds 1.95 3.5 4.0
# Funds 466.4
#
# Prediction 2
# Actual 2
# Favourite 0
# Prediction proba [0.11274865 0.2782299  0.6090215 ]
# Home, Draw and Away odds 2.45 3.2 3.0
# Funds 486.4
#
# Prediction 0
# Actual 0
# Favourite 0
# Prediction proba [0.86119425 0.12393412 0.01487169]
# Home, Draw and Away odds 1.36 5.25 8.0
# Funds 490.0
#
# Prediction 2
# Actual 2
# Favourite 2
# Prediction proba [0.01552591 0.15368104 0.830793  ]
# Home, Draw and Away odds 2.9 3.3 2.5
# Funds 505.0
#
# Prediction 2
# Actual 0
# Favourite 2
# Prediction proba [0.3354795  0.27466264 0.38985786]
# Home, Draw and Away odds 15.0 9.0 1.14
# Funds 505.0
#
# Prediction 0
# Actual 0
# Favourite 2
# Prediction proba [0.61061317 0.28613815 0.10324867]
# Home, Draw and Away odds 2.9 3.5 2.4
# Funds 524.0
#
# Prediction 1
# Actual 1
# Favourite 2
# Prediction proba [0.37932914 0.4089119  0.21175893]
# Home, Draw and Away odds 3.6 3.6 2.0
# Funds 550.0
#
# Prediction 0
# Actual 1
# Favourite 2
# Prediction proba [0.433301   0.27731884 0.28938013]
# Home, Draw and Away odds 2.62 3.5 2.6
# Funds 540.0
#
# Prediction 1
# Actual 2
# Favourite 0
# Prediction proba [0.32733166 0.38566923 0.2869991 ]
# Home, Draw and Away odds 2.05 3.6 3.5
# Funds 530.0
#
# Prediction 0
# Actual 0
# Favourite 2
# Prediction proba [0.42997634 0.30331582 0.26670778]
# Home, Draw and Away odds 2.87 3.5 2.37
# Funds 548.7
#
# Prediction 0
# Actual 0
# Favourite 0
# Prediction proba [0.60326093 0.27684736 0.11989173]
# Home, Draw and Away odds 2.0 3.8 3.5
# Funds 558.7
#
# Prediction 2
# Actual 2
# Favourite 0
# Prediction proba [0.02314567 0.23853979 0.73831457]
# Home, Draw and Away odds 1.61 3.75 6.0
# Funds 608.7
#
# Prediction 0
# Actual 0
# Favourite 0
# Prediction proba [9.9532300e-01 4.4874423e-03 1.8957096e-04]
# Home, Draw and Away odds 1.1 11.0 21.0
# Funds 609.7
#
# Prediction 0
# Actual 1
# Favourite 0
# Prediction proba [0.5573862  0.29344887 0.14916499]
# Home, Draw and Away odds 2.5 3.2 3.0
# Funds 599.7
#
# Prediction 1
# Actual 1
# Favourite 0
# Prediction proba [0.3425836  0.36090833 0.2965081 ]
# Home, Draw and Away odds 2.62 3.1 2.87
# Funds 620.7
#
# Prediction 0
# Actual 0
# Favourite 2
# Prediction proba [0.89303917 0.07950706 0.02745378]
# Home, Draw and Away odds 3.1 3.6 2.2
# Funds 641.7
#
# Prediction 0
# Actual 0
# Favourite 0
# Prediction proba [0.3743584 0.2732866 0.352355 ]
# Home, Draw and Away odds 1.4 4.75 8.0
# Funds 641.7
#
# Prediction 1
# Actual 2
# Favourite 2
# Prediction proba [0.22469716 0.38830036 0.3870025 ]
# Home, Draw and Away odds 3.5 3.75 2.0
# Funds 631.7
#
# Prediction 1
# Actual 2
# Favourite 2
# Prediction proba [0.25732794 0.4176884  0.3249837 ]
# Home, Draw and Away odds 9.0 5.25 1.33
# Funds 621.7
#
# Prediction 0
# Actual 1
# Favourite 0
# Prediction proba [0.4125481  0.3044613  0.28299063]
# Home, Draw and Away odds 2.3 3.4 3.1
# Funds 621.7
#
# Prediction 2
# Actual 1
# Favourite 0
# Prediction proba [0.34906423 0.26894855 0.3819872 ]
# Home, Draw and Away odds 2.5 3.5 2.75
# Funds 621.7
#
# Prediction 0
# Actual 0
# Favourite 0
# Prediction proba [0.92498964 0.06979891 0.00521144]
# Home, Draw and Away odds 1.4 4.75 8.0
# Funds 625.7
#
# Prediction 1
# Actual 0
# Favourite 0
# Prediction proba [0.3218233  0.3538311  0.32434565]
# Home, Draw and Away odds 1.9 3.75 3.75
# Funds 615.7
#
# Prediction 0
# Actual 0
# Favourite 0
# Prediction proba [0.74764323 0.18597381 0.06638292]
# Home, Draw and Away odds 1.4 4.75 8.0
# Funds 619.7
#
# Prediction 0
# Actual 0
# Favourite 0
# Prediction proba [0.81939155 0.1594116  0.02119687]
# Home, Draw and Away odds 1.85 3.4 4.5
# Funds 628.2
#
# Prediction 2
# Actual 2
# Favourite 2
# Prediction proba [0.00813266 0.08643514 0.90543216]
# Home, Draw and Away odds 10.0 5.5 1.3
# Funds 631.2
#
# Prediction 0
# Actual 0
# Favourite 0
# Prediction proba [0.9659531  0.0320861  0.00196082]
# Home, Draw and Away odds 1.5 4.0 7.5
# Funds 636.2
#
# Prediction 0
# Actual 1
# Favourite 0
# Prediction proba [0.66796374 0.1878702  0.14416608]
# Home, Draw and Away odds 2.37 3.5 2.9
# Funds 626.2
#
# Prediction 0
# Actual 0
# Favourite 2
# Prediction proba [0.454674   0.30071312 0.24461283]
# Home, Draw and Away odds 3.9 3.6 1.9
# Funds 655.2
#
# Prediction 0
# Actual 0
# Favourite 2
# Prediction proba [0.83930767 0.1249354  0.03575691]
# Home, Draw and Away odds 2.87 3.3 2.5
# Funds 673.9000000000001
#
# Prediction 1
# Actual 0
# Favourite 0
# Prediction proba [0.33069336 0.41105184 0.2582548 ]
# Home, Draw and Away odds 1.44 4.75 7.0
# Funds 663.9000000000001
#
# Prediction 2
# Actual 2
# Favourite 0
# Prediction proba [0.04516236 0.16271834 0.79211926]
# Home, Draw and Away odds 2.37 3.6 2.8
# Funds 681.9000000000001
#
# Prediction 2
# Actual 1
# Favourite 0
# Prediction proba [0.20986031 0.26627904 0.5238606 ]
# Home, Draw and Away odds 2.05 3.4 3.6
# Funds 671.9000000000001
#
# Prediction 0
# Actual 2
# Favourite 0
# Prediction proba [0.6874191  0.23576672 0.07681419]
# Home, Draw and Away odds 1.95 3.6 3.8
# Funds 661.9000000000001
#
# Prediction 0
# Actual 0
# Favourite 0
# Prediction proba [0.5731275  0.28930393 0.13756867]
# Home, Draw and Away odds 1.44 4.75 7.0
# Funds 661.9000000000001
#
# Prediction 0
# Actual 2
# Favourite 0
# Prediction proba [0.78039247 0.12323035 0.09637718]
# Home, Draw and Away odds 1.12 9.0 21.0
# Funds 661.9000000000001
#
# Prediction 2
# Actual 2
# Favourite 2
# Prediction proba [0.11573537 0.2759245  0.6083401 ]
# Home, Draw and Away odds 4.0 3.8 1.85
# Funds 670.4000000000001
#
# Prediction 0
# Actual 0
# Favourite 2
# Prediction proba [0.3990045 0.2947975 0.3061981]
# Home, Draw and Away odds 4.5 3.5 1.85
# Funds 705.4000000000001
#
# Prediction 2
# Actual 0
# Favourite 0
# Prediction proba [0.22299914 0.3638644  0.4131365 ]
# Home, Draw and Away odds 1.95 3.75 3.75
# Funds 695.4000000000001
#
# Prediction 0
# Actual 0
# Favourite 0
# Prediction proba [0.7775597  0.18999158 0.03244868]
# Home, Draw and Away odds 2.35 3.4 3.0
# Funds 708.9000000000001
#
# Prediction 0
# Actual 1
# Favourite 0
# Prediction proba [0.7866029  0.17560738 0.03778974]
# Home, Draw and Away odds 1.72 4.2 4.2
# Funds 698.9000000000001
#
# Prediction 0
# Actual 0
# Favourite 0
# Prediction proba [0.95262545 0.04420788 0.00316669]
# Home, Draw and Away odds 1.3 5.5 10.0
# Funds 701.9000000000001
#
# Prediction 0
# Actual 0
# Favourite 0
# Prediction proba [0.6917997  0.26237428 0.04582603]
# Home, Draw and Away odds 1.57 4.0 6.0
# Funds 707.6000000000001
#
# Prediction 0
# Actual 1
# Favourite 0
# Prediction proba [0.7383586  0.19954115 0.06210025]
# Home, Draw and Away odds 1.4 5.0 7.5
# Funds 707.6000000000001
#
# Prediction 0
# Actual 1
# Favourite 0
# Prediction proba [0.46416453 0.33442566 0.20140974]
# Home, Draw and Away odds 1.8 3.6 4.5
# Funds 707.6000000000001
#
# Prediction 2
# Actual 2
# Favourite 2
# Prediction proba [0.00155887 0.02693372 0.97150743]
# Home, Draw and Away odds 12.0 7.0 1.22
# Funds 709.8000000000002
#
# Prediction 1
# Actual 1
# Favourite 2
# Prediction proba [0.09380966 0.46733475 0.43885565]
# Home, Draw and Away odds 5.25 3.8 1.65
# Funds 737.8000000000002
#
# Prediction 0
# Actual 0
# Favourite 2
# Prediction proba [0.6624023  0.26116326 0.07643445]
# Home, Draw and Away odds 3.9 3.75 1.9
# Funds 766.8000000000002
#
# Prediction 2
# Actual 2
# Favourite 2
# Prediction proba [0.00166614 0.03682884 0.961505  ]
# Home, Draw and Away odds 3.1 3.4 2.3
# Funds 779.8000000000002
#
# Prediction 0
# Actual 0
# Favourite 0
# Prediction proba [0.88732517 0.09935258 0.01332221]
# Home, Draw and Away odds 1.08 11.0 26.0
# Funds 779.8000000000002
#
# Prediction 0
# Actual 0
# Favourite 2
# Prediction proba [0.43633947 0.32269603 0.2409645 ]
# Home, Draw and Away odds 2.9 3.25 2.5
# Funds 798.8000000000002
#
# Prediction 2
# Actual 1
# Favourite 0
# Prediction proba [0.2078823  0.26467925 0.5274384 ]
# Home, Draw and Away odds 2.15 3.6 3.25
# Funds 788.8000000000002
#
# Prediction 0
# Actual 1
# Favourite 0
# Prediction proba [0.46763474 0.36870596 0.16365924]
# Home, Draw and Away odds 2.1 3.5 3.5
# Funds 788.8000000000002
#
# Prediction 2
# Actual 2
# Favourite 2
# Prediction proba [0.04132748 0.19080213 0.7678704 ]
# Home, Draw and Away odds 4.5 4.0 1.72
# Funds 796.0000000000002
#
# Prediction 2
# Actual 1
# Favourite 2
# Prediction proba [0.23887578 0.32557175 0.43555245]
# Home, Draw and Away odds 3.0 3.1 2.55
# Funds 786.0000000000002
#
# Prediction 0
# Actual 1
# Favourite 0
# Prediction proba [0.48432282 0.27782372 0.2378534 ]
# Home, Draw and Away odds 1.45 4.75 6.5
# Funds 786.0000000000002
#
# Prediction 0
# Actual 0
# Favourite 0
# Prediction proba [0.50143737 0.2843066  0.21425608]
# Home, Draw and Away odds 1.5 4.33 6.5
# Funds 786.0000000000002
#
# Prediction 2
# Actual 2
# Favourite 2
# Prediction proba [0.0994179  0.23078527 0.6697968 ]
# Home, Draw and Away odds 4.33 4.0 1.75
# Funds 793.5000000000002
#
# Prediction 0
# Actual 0
# Favourite 2
# Prediction proba [0.56091225 0.31278598 0.12630181]
# Home, Draw and Away odds 3.25 3.6 2.15
# Funds 816.0000000000002
#
# Prediction 1
# Actual 1
# Favourite 0
# Prediction proba [0.15401806 0.42700008 0.41898182]
# Home, Draw and Away odds 1.75 3.75 4.75
# Funds 843.5000000000002
#
# Prediction 0
# Actual 2
# Favourite 2
# Prediction proba [0.4971351  0.28611097 0.21675393]
# Home, Draw and Away odds 9.0 5.0 1.33
# Funds 833.5000000000002
#
# Prediction 0
# Actual 0
# Favourite 0
# Prediction proba [0.6136406  0.27389714 0.11246224]
# Home, Draw and Away odds 1.72 4.2 4.33
# Funds 840.7000000000003
#
# Prediction 0
# Actual 0
# Favourite 0
# Prediction proba [0.9852879  0.01316738 0.00154481]
# Home, Draw and Away odds 1.07 13.0 23.0
# Funds 841.4000000000003
#
# Prediction 0
# Actual 0
# Favourite 0
# Prediction proba [0.73010874 0.2327975  0.03709381]
# Home, Draw and Away odds 2.25 3.2 3.4
# Funds 853.9000000000003
#
# Prediction 0
# Actual 2
# Favourite 0
# Prediction proba [0.35812792 0.34961653 0.29225555]
# Home, Draw and Away odds 1.75 3.8 4.5
# Funds 853.9000000000003
#
# Prediction 2
# Actual 2
# Favourite 2
# Prediction proba [0.03957732 0.12062935 0.8397933 ]
# Home, Draw and Away odds 5.0 4.33 1.61
# Funds 860.0000000000003
#
# Prediction 2
# Actual 2
# Favourite 2
# Prediction proba [0.00825867 0.11684725 0.8748941 ]
# Home, Draw and Away odds 3.5 3.4 2.1
# Funds 871.0000000000003
#
# Prediction 0
# Actual 1
# Favourite 2
# Prediction proba [0.38178858 0.29086918 0.32734224]
# Home, Draw and Away odds 2.7 3.4 2.6
# Funds 871.0000000000003
#
# Prediction 2
# Actual 2
# Favourite 2
# Prediction proba [0.16257024 0.34101042 0.4964194 ]
# Home, Draw and Away odds 2.7 3.5 2.55
# Funds 886.5000000000003
#
# Prediction 0
# Actual 0
# Favourite 0
# Prediction proba [0.9128099  0.07674456 0.0104455 ]
# Home, Draw and Away odds 1.33 5.0 10.0
# Funds 889.8000000000003
#
# Prediction 2
# Actual 0
# Favourite 0
# Prediction proba [0.22162811 0.32937708 0.44899482]
# Home, Draw and Away odds 2.25 3.5 3.1
# Funds 879.8000000000003
#
# Prediction 0
# Actual 0
# Favourite 0
# Prediction proba [0.4350297  0.290279   0.27469128]
# Home, Draw and Away odds 2.55 3.25 2.8
# Funds 895.3000000000003
#
# Prediction 2
# Actual 2
# Favourite 2
# Prediction proba [0.12242732 0.2789082  0.59866446]
# Home, Draw and Away odds 2.9 3.3 2.45
# Funds 909.8000000000003
#
# Prediction 0
# Actual 1
# Favourite 0
# Prediction proba [0.5361877  0.31367826 0.15013406]
# Home, Draw and Away odds 1.57 4.0 6.0
# Funds 909.8000000000003
#
# Prediction 0
# Actual 0
# Favourite 0
# Prediction proba [0.96731275 0.03151236 0.0011748 ]
# Home, Draw and Away odds 2.0 3.75 3.5
# Funds 919.8000000000003
#
# Prediction 0
# Actual 0
# Favourite 0
# Prediction proba [0.61022365 0.26241836 0.12735797]
# Home, Draw and Away odds 1.6 3.75 6.5
# Funds 919.8000000000003
#
# Prediction 0
# Actual 0
# Favourite 0
# Prediction proba [0.56991297 0.3168526  0.11323447]
# Home, Draw and Away odds 1.9 3.5 4.2
# Funds 928.8000000000003
#
# Prediction 2
# Actual 0
# Favourite 0
# Prediction proba [0.2448568  0.32980025 0.42534292]
# Home, Draw and Away odds 2.5 3.6 2.62
# Funds 918.8000000000003
# Betted on favourite 74 times out of 118 matches.
# No bet placed 31 times
