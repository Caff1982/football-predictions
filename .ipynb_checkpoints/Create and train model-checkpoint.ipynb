# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import os
import random

# Set random seed for reproducibility
np.random.seed(42)
random.seed(42)
os.environ['PYTHONHASHSEED'] = str(42)

from keras import backend as K
config = tf.ConfigProto(intra_op_parallelism_threads=1,inter_op_parallelism_threads=1)
tf.set_random_seed(42)
sess = tf.Session(config=config)
K.set_session(sess)

import keras
from keras.layers import Dense, Dropout, BatchNormalization
from keras.callbacks import EarlyStopping

from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.preprocessing import StandardScaler



DATA_PATH = 'data/'
# Out:
# /home/stephen/Projects/betting_model/env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/stephen/Projects/betting_model/env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/stephen/Projects/betting_model/env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/stephen/Projects/betting_model/env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/stephen/Projects/betting_model/env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/stephen/Projects/betting_model/env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/stephen/Projects/betting_model/env/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/stephen/Projects/betting_model/env/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/stephen/Projects/betting_model/env/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/stephen/Projects/betting_model/env/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/stephen/Projects/betting_model/env/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/stephen/Projects/betting_model/env/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.

# %% [markdown]
# # Prepare the data
#
# We first need to load both our league-data and EMA data and combine these together.

# %%
league_data = pd.read_csv('data/league_data.csv')
league_data.drop(['Unnamed: 0', 'Date', 'HomeTeam', 'AwayTeam', 
                 'HTGS', 'ATGS', 'HTGC', 'ATGC', 'HM1', 'HM2', 'HM3', 
                 'HM4', 'HM5', 'AM1', 'AM2', 'AM3', 'AM4', 'AM5', 'HTFormPts',
                 'ATFormPts', 'MW', 'HTFormPtsStr', 'ATFormPtsStr'], 1, inplace=True)
league_data.columns
# Out:
# Index(['season', 'FTR', 'HTP', 'ATP', 'B365H', 'B365D', 'B365A', 'gameId',
#        'HTGD', 'ATGD', 'DiffPts', 'DiffFormPts', 'DiffLP'],
#       dtype='object')

# %%
EMA_data = pd.read_csv('data/EMA_data.csv')
EMA_data.drop(['Unnamed: 0', 'f_DateHome', 'f_seasonHome', 'HomeTeam',
               'homeGame_x', 'f_yellowsAgainstAway', 'f_yellowsForAway',
               'f_yellowsAgainstHome', 'f_yellowsForHome', 'f_DateAway', 'f_seasonAway', 
               'AwayTeam', 'homeGame_y'], 1, inplace=True)
EMA_data.columns
# Out:
# Index(['gameId', 'f_cornersAgainstHome', 'f_cornersForHome',
#        'f_freesAgainstHome', 'f_freesForHome', 'f_goalsAgainstHome',
#        'f_goalsForHome', 'f_halfTimeGoalsAgainstHome',
#        'f_halfTimeGoalsForHome', 'f_redsAgainstHome', 'f_redsForHome',
#        'f_shotsAgainstHome', 'f_shotsForHome', 'f_shotsOnTargetAgainstHome',
#        'f_shotsOnTargetForHome', 'f_cornersAgainstAway', 'f_cornersForAway',
#        'f_freesAgainstAway', 'f_freesForAway', 'f_goalsAgainstAway',
#        'f_goalsForAway', 'f_halfTimeGoalsAgainstAway',
#        'f_halfTimeGoalsForAway', 'f_redsAgainstAway', 'f_redsForAway',
#        'f_shotsAgainstAway', 'f_shotsForAway', 'f_shotsOnTargetAgainstAway',
#        'f_shotsOnTargetForAway'],
#       dtype='object')

# %%
df = pd.merge(EMA_data, league_data, left_on='gameId', right_index=True)
df.head()
# Out:
#    gameId  gameId_x  f_cornersAgainstHome  f_cornersForHome  \
# 0      18        18                 10.94              6.55
# 1      20        20                  9.06              6.00
# 2      21        21                 11.49              3.51
# 3      22        22                  5.47              5.57
# 4      23        23                  4.47              3.53
#
#    f_freesAgainstHome  f_freesForHome  f_goalsAgainstHome  f_goalsForHome  \
# 0                9.57           19.00                1.49            1.51
# 1                9.41           14.96                1.49            1.49
# 2               12.08           15.49                1.02            0.51
# 3               11.45           15.02                2.02            0.51
# 4               14.12           10.45                0.98            1.00
#
#    f_halfTimeGoalsAgainstHome  f_halfTimeGoalsForHome  ...       ATP  B365H  \
# 0                        0.51                    1.51  ...  0.000000   2.10
# 1                        1.00                    0.49  ...  0.000000   1.83
# 2                        0.00                    0.51  ...  2.000000   2.50
# 3                        1.53                    0.51  ...  0.333333   1.44
# 4                        0.49                    0.00  ...  1.333333   2.20
#
#    B365D  B365A  gameId_y      HTGD      ATGD   DiffPts  DiffFormPts  DiffLP
# 0   3.25   3.40        19  0.500000 -0.500000  0.000000     0.000000       0
# 1   3.30   4.33        21  0.666667 -1.000000  0.666667     0.666667       0
# 2   3.25   2.70        22  0.000000  0.333333 -1.666667    -1.666667       0
# 3   4.00   7.50        23  0.666667 -1.666667 -0.333333    -0.333333       0
# 4   3.25   3.20        24  1.333333 -1.000000 -0.333333    -0.333333       0
#
# [5 rows x 43 columns]

# %% [markdown]
# # Cleaning and splitting the data
#
# Because the machine -learning model only takes numeric input we will change our labels from strings to integers and use categorical cross-entropy as our loss function. We will also scale our data using sklearn StandardScaler.
#
# First we will seperate the labels from the rest of our data and split into training and testing.

# %%
training_data = df.loc[df['season'] != 1920].reset_index(drop=True)
testing_data = df.loc[df['season'] == 1920].reset_index(drop=True)

X = training_data.drop(['gameId', 'gameId_x', 'gameId_y', 'FTR', 
           'season', 'gameId_y', ], 1)
Y = training_data['FTR']

X_test = testing_data.drop(['gameId', 'gameId_x', 'gameId_y', 'FTR', 
           'season', 'gameId_y', ], 1)
y_test = testing_data['FTR']

# %%
testing_data.tail()
# Out:
#      gameId  gameId_x  f_cornersAgainstHome  f_cornersForHome  \
# 123    4685      4685              5.978293          4.809925
# 124    4686      4686              4.565659          6.002476
# 125    4687      4687              5.551670          4.676105
# 126    4688      4688              2.394241          8.241461
# 127    4689      4689              6.506138          6.033564
#
#      f_freesAgainstHome  f_freesForHome  f_goalsAgainstHome  f_goalsForHome  \
# 123           11.702112       11.004062            1.420448        1.265252
# 124           10.557303       11.607718            1.295098        1.288115
# 125            8.990351       11.080792            1.731395        1.044866
# 126            8.321039        9.099733            0.796715        2.561447
# 127            8.084640       10.255848            0.718892        1.103651
#
#      f_halfTimeGoalsAgainstHome  f_halfTimeGoalsForHome  ...       ATP  B365H  \
# 123                    0.532886                0.465308  ...  0.538462   1.36
# 124                    0.446414                0.649212  ...  1.153846   2.30
# 125                    0.835796                0.388996  ...  2.000000   1.44
# 126                    0.430477                1.210825  ...  1.230769   3.50
# 127                    0.316085                0.468612  ...  1.153846   3.50
#
#      B365D  B365A  gameId_y      HTGD      ATGD   DiffPts  DiffFormPts  DiffLP
# 123    5.1    8.0      4686 -0.538462 -0.923077  0.538462     0.461538       0
# 124    3.4    3.1      4687 -1.153846 -0.076923 -0.538462     0.000000       0
# 125    5.0    6.5      4688  1.384615  1.000000 -0.076923    -0.461538       0
# 126    3.4    2.1      4689  0.307692  0.000000  0.076923     0.153846       0
# 127    3.4    2.1      4690 -0.076923 -0.461538 -0.307692    -0.307692       0
#
# [5 rows x 43 columns]

# %%
def transform_results(results):
    transformed = []
    for i in range(len(results)):
        if results[i] == 'H':
            transformed.append(0)
        elif results[i] == 'A':
            transformed.append(2)
        else:
            transformed.append(1)
    return np.array(transformed)
            
Y = transform_results(Y)
y_test = transform_results(y_test)

# %%
scaler = StandardScaler()

X = scaler.fit_transform(X)
X_test = scaler.fit_transform(X_test)

# %%
print('Number of matches in training data:', X.shape[0])
print('Number of matches in test data:', X_test.shape[0])
print('Number of features:', X.shape[1])
# Out:
# Number of matches in training data: 4503
# Number of matches in test data: 128
# Number of features: 38

# %%
# Split our data. We are using the most recent season for validation
X_train = X[:-380]
y_train = Y[:-380]
X_val = X[-380:]
y_val = Y[-380:]

# %% [markdown]
# # Build the model
#
# Now we have cleaned the data we can now create our model and train it.

# %%
# input dimension is number of features
input_dim = X_train.shape[1]

activation_func = 'relu'
kernel_init = 'glorot_normal'
learning_rate = 0.001
batch_size = 16

model = keras.Sequential([
    Dense(48, input_shape=(input_dim,), activation=activation_func),
    Dropout(0.3),
    Dense(16),
    Dropout(0.2),
    Dense(3, activation='softmax')
])

# %%
es = EarlyStopping(monitor='loss', patience=3, verbose=1)

# %%
from keras.optimizers import Adam, SGD

opt = Adam(lr=learning_rate, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
model.compile(optimizer=opt, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(X_train, y_train, batch_size=batch_size, 
              callbacks=[es], epochs=500, verbose=0)
# Out:
# WARNING:tensorflow:From /home/stephen/Projects/betting_model/env/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Epoch 00030: early stopping

# %%
train_loss, train_acc = model.evaluate(X_train, y_train)
val_loss, val_acc = model.evaluate(X_val, y_val)
print('Training loss:', train_loss)
print('Training accuracy:', train_acc)
print('Validation loss:', val_loss)
print('Validation accuracy:', val_acc)
# Out:
# 4123/4123 [==============================] - 0s 12us/step
# 380/380 [==============================] - 0s 20us/step
# Training loss: 0.7936528218680148
# Training accuracy: 0.6480717658996582
# Validation loss: 0.8073749272446883
# Validation accuracy: 0.6184210777282715

# %% [markdown]
# We are getting around 65% on training and 62% on validation. This is good as is well above the bookies accuracy. Once we are happy with how the model is performing we can check the accuracy on the test set

# %%
# Saving best model
# model.save('25Nov19.h5')

# %%
test_loss, test_acc = model.evaluate(X_test, y_test)
print('Test loss:', test_loss)
print('Test accuracy:', test_acc)
# Out:
# 128/128 [==============================] - 0s 30us/step
# Test loss: 0.7197954952716827
# Test accuracy: 0.6640625

# %% [markdown]
# # Create a betting strategy
#
# Now that we have an accurate model let's see if we can make it as profitable as possible.

# %% [markdown]
# Our confusion matrix looks good. I mainly wanted to check the performance for draws as these are difficult to predict, the results are ok.
#
# We will now use the for-loop below to see how much we would have won had we bet.

# %%
funds = 100
wager = 10
favourites = 0
no_bets = 0
min_diff = 0.03

y_preds = model.predict(X_test)

for i in range(len(X_test)):
    prediction = np.argmax(y_preds[i])
    print('\nPrediction', prediction)
    print('Actual', y_test[i])
    print('Favourite', np.argmin([testing_data['B365H'][i], testing_data['B365D'][i], 
                                  testing_data['B365A'][i]]))
    print('Prediction proba', y_preds[i])
    print('Home, Draw and Away odds', testing_data['B365H'][i],       
          testing_data['B365D'][i], testing_data['B365A'][i])
    
    if prediction == 0:
        odds_diff = y_preds[i][prediction] - (1/testing_data['B365H'][i])
        if odds_diff > min_diff:
            if prediction == np.argmin([testing_data['B365H'][i], testing_data['B365D'][i], 
                                  testing_data['B365A'][i]]):
                favourites +=1
                
            if  prediction == y_test[i]:
                funds += (wager * testing_data['B365H'][i]) - wager
            else:
                funds -= wager
        else:
            no_bets +=1
            
    elif prediction == 1:
        odds_diff = y_preds[i][prediction] - (1/testing_data['B365D'][i])
        if odds_diff > min_diff:
            if prediction == np.argmin([testing_data['B365H'][i], testing_data['B365D'][i], 
                                  testing_data['B365A'][i]]):
                favourites +=1
            if  prediction == y_test[i]:
                funds +=( wager * testing_data['B365D'][i]) - wager
            else:
                funds -= wager
        else:
            no_bets +=1
    else:
        odds_diff = y_preds[i][prediction] - (1/testing_data['B365A'][i])
        if odds_diff >  min_diff:
            if prediction == np.argmin([testing_data['B365H'][i], testing_data['B365D'][i], 
                                  testing_data['B365A'][i]]):
                favourites +=1
            if  prediction == y_test[i]:
                funds += (wager * testing_data['B365A'][i]) - wager
            else:
                funds -= wager
        else:
            no_bets +=1
   
    print('Funds', funds)
    
print(f'Betted on favourite {favourites} times out of {len(X_test)} matches.')
print(f'No bet placed {no_bets} times')
# Out:
# Prediction 0
# Actual 0
# Favourite 0
# Prediction proba [0.6406146  0.2976048  0.06178055]
# Home, Draw and Away odds 1.14 10.0 19.0
# Funds 100
#
# Prediction 2
# Actual 2
# Favourite 2
# Prediction proba [0.1498708  0.09711154 0.75301766]
# Home, Draw and Away odds 12.0 6.5 1.22
# Funds 100
#
# Prediction 2
# Actual 1
# Favourite 0
# Prediction proba [0.24385048 0.229821   0.5263285 ]
# Home, Draw and Away odds 1.95 3.6 3.6
# Funds 90
#
# Prediction 2
# Actual 1
# Favourite 2
# Prediction proba [0.23566064 0.30126706 0.46307233]
# Home, Draw and Away odds 3.0 3.25 2.37
# Funds 80
#
# Prediction 2
# Actual 2
# Favourite 0
# Prediction proba [0.26342666 0.29570556 0.44086778]
# Home, Draw and Away odds 1.9 3.4 4.0
# Funds 110.0
#
# Prediction 0
# Actual 0
# Favourite 0
# Prediction proba [0.36956793 0.30569366 0.32473844]
# Home, Draw and Away odds 1.3 5.25 10.0
# Funds 110.0
#
# Prediction 2
# Actual 1
# Favourite 0
# Prediction proba [0.21831408 0.30487978 0.4768061 ]
# Home, Draw and Away odds 2.2 3.2 3.4
# Funds 100.0
#
# Prediction 2
# Actual 2
# Favourite 2
# Prediction proba [0.2946113  0.26048014 0.4449086 ]
# Home, Draw and Away odds 4.5 3.75 1.72
# Funds 100.0
#
# Prediction 0
# Actual 0
# Favourite 0
# Prediction proba [0.37752527 0.3628586  0.25961617]
# Home, Draw and Away odds 2.1 3.3 3.5
# Funds 100.0
#
# Prediction 0
# Actual 0
# Favourite 0
# Prediction proba [0.89909834 0.09014284 0.01075882]
# Home, Draw and Away odds 1.3 5.5 10.0
# Funds 103.0
#
# Prediction 2
# Actual 2
# Favourite 0
# Prediction proba [0.11606686 0.35145605 0.53247714]
# Home, Draw and Away odds 2.3 3.4 3.1
# Funds 124.0
#
# Prediction 1
# Actual 1
# Favourite 0
# Prediction proba [0.16970345 0.5340957  0.29620087]
# Home, Draw and Away odds 2.55 3.25 2.87
# Funds 146.5
#
# Prediction 0
# Actual 0
# Favourite 0
# Prediction proba [0.78487873 0.17881061 0.03631065]
# Home, Draw and Away odds 1.72 3.8 4.75
# Funds 153.7
#
# Prediction 0
# Actual 0
# Favourite 0
# Prediction proba [0.9675049  0.03002689 0.00246819]
# Home, Draw and Away odds 2.25 3.3 3.3
# Funds 166.2
#
# Prediction 1
# Actual 2
# Favourite 2
# Prediction proba [0.3456446  0.5388462  0.11550917]
# Home, Draw and Away odds 6.5 4.75 1.44
# Funds 156.2
#
# Prediction 0
# Actual 1
# Favourite 0
# Prediction proba [0.4847176  0.3170922  0.19819012]
# Home, Draw and Away odds 1.36 5.25 8.0
# Funds 156.2
#
# Prediction 0
# Actual 0
# Favourite 0
# Prediction proba [0.9370946  0.04977472 0.01313063]
# Home, Draw and Away odds 2.55 3.1 2.9
# Funds 171.7
#
# Prediction 0
# Actual 1
# Favourite 2
# Prediction proba [0.6437936  0.23392832 0.12227805]
# Home, Draw and Away odds 3.3 3.3 2.25
# Funds 161.7
#
# Prediction 0
# Actual 0
# Favourite 2
# Prediction proba [0.89050585 0.10382749 0.00566661]
# Home, Draw and Away odds 3.25 3.5 2.15
# Funds 184.2
#
# Prediction 1
# Actual 2
# Favourite 2
# Prediction proba [0.11229917 0.4603312  0.4273696 ]
# Home, Draw and Away odds 4.33 3.75 1.8
# Funds 174.2
#
# Prediction 2
# Actual 2
# Favourite 0
# Prediction proba [0.00548738 0.08699573 0.9075169 ]
# Home, Draw and Away odds 2.4 3.3 3.0
# Funds 194.2
#
# Prediction 2
# Actual 2
# Favourite 0
# Prediction proba [0.04704666 0.17446572 0.7784877 ]
# Home, Draw and Away odds 1.33 5.25 9.0
# Funds 274.2
#
# Prediction 2
# Actual 2
# Favourite 2
# Prediction proba [0.12715577 0.26813763 0.6047066 ]
# Home, Draw and Away odds 3.3 3.3 2.25
# Funds 286.7
#
# Prediction 2
# Actual 2
# Favourite 0
# Prediction proba [0.00775642 0.09657579 0.8956678 ]
# Home, Draw and Away odds 2.05 3.5 3.5
# Funds 311.7
#
# Prediction 0
# Actual 0
# Favourite 0
# Prediction proba [0.9283933  0.06917258 0.00243417]
# Home, Draw and Away odds 1.5 4.6 6.0
# Funds 316.7
#
# Prediction 2
# Actual 2
# Favourite 2
# Prediction proba [0.01725761 0.02548292 0.9572594 ]
# Home, Draw and Away odds 15.0 7.5 1.16
# Funds 318.3
#
# Prediction 2
# Actual 2
# Favourite 0
# Prediction proba [0.09463763 0.29091278 0.6144496 ]
# Home, Draw and Away odds 1.2 6.5 14.0
# Funds 448.3
#
# Prediction 0
# Actual 1
# Favourite 0
# Prediction proba [0.6402742  0.26969323 0.09003254]
# Home, Draw and Away odds 1.85 3.4 4.5
# Funds 438.3
#
# Prediction 0
# Actual 1
# Favourite 2
# Prediction proba [0.6482769  0.28831637 0.0634067 ]
# Home, Draw and Away odds 3.8 3.3 2.05
# Funds 428.3
#
# Prediction 0
# Actual 1
# Favourite 0
# Prediction proba [0.56815594 0.27338547 0.15845855]
# Home, Draw and Away odds 1.36 4.75 9.0
# Funds 428.3
#
# Prediction 0
# Actual 0
# Favourite 0
# Prediction proba [0.5798474  0.18216074 0.23799178]
# Home, Draw and Away odds 2.15 3.3 3.5
# Funds 439.8
#
# Prediction 0
# Actual 0
# Favourite 0
# Prediction proba [0.8863887  0.10181738 0.01179385]
# Home, Draw and Away odds 1.7 4.0 4.75
# Funds 446.8
#
# Prediction 0
# Actual 0
# Favourite 0
# Prediction proba [9.716123e-01 2.770644e-02 6.812615e-04]
# Home, Draw and Away odds 1.08 10.0 26.0
# Funds 447.6
#
# Prediction 0
# Actual 1
# Favourite 0
# Prediction proba [0.377117   0.29776108 0.32512194]
# Home, Draw and Away odds 2.5 3.25 2.87
# Funds 447.6
#
# Prediction 0
# Actual 0
# Favourite 0
# Prediction proba [0.8404777  0.13208094 0.02744139]
# Home, Draw and Away odds 1.85 3.9 3.9
# Funds 456.1
#
# Prediction 2
# Actual 2
# Favourite 2
# Prediction proba [0.01634329 0.15411316 0.82954353]
# Home, Draw and Away odds 9.5 5.5 1.3
# Funds 459.1
#
# Prediction 0
# Actual 0
# Favourite 0
# Prediction proba [0.36875802 0.35252807 0.2787139 ]
# Home, Draw and Away odds 2.2 3.25 3.5
# Funds 459.1
#
# Prediction 2
# Actual 1
# Favourite 0
# Prediction proba [0.28891778 0.34037805 0.37070414]
# Home, Draw and Away odds 2.37 3.6 2.8
# Funds 459.1
#
# Prediction 0
# Actual 0
# Favourite 0
# Prediction proba [0.9599354  0.02977776 0.01028678]
# Home, Draw and Away odds 1.14 8.5 17.0
# Funds 460.5
#
# Prediction 2
# Actual 1
# Favourite 0
# Prediction proba [0.32637566 0.28927508 0.38434923]
# Home, Draw and Away odds 2.15 3.3 3.5
# Funds 450.5
#
# Prediction 0
# Actual 0
# Favourite 0
# Prediction proba [0.474701   0.43327123 0.09202788]
# Home, Draw and Away odds 1.95 3.5 4.0
# Funds 450.5
#
# Prediction 2
# Actual 2
# Favourite 0
# Prediction proba [0.10099071 0.30057248 0.5984368 ]
# Home, Draw and Away odds 2.45 3.2 3.0
# Funds 470.5
#
# Prediction 0
# Actual 0
# Favourite 0
# Prediction proba [0.96281374 0.0358294  0.0013569 ]
# Home, Draw and Away odds 1.36 5.25 8.0
# Funds 474.1
#
# Prediction 2
# Actual 2
# Favourite 2
# Prediction proba [0.03273064 0.08011069 0.8871586 ]
# Home, Draw and Away odds 2.9 3.3 2.5
# Funds 489.1
#
# Prediction 0
# Actual 0
# Favourite 2
# Prediction proba [0.61294085 0.20833781 0.17872135]
# Home, Draw and Away odds 15.0 9.0 1.14
# Funds 629.1
#
# Prediction 0
# Actual 0
# Favourite 2
# Prediction proba [0.7154485  0.19604036 0.08851113]
# Home, Draw and Away odds 2.9 3.5 2.4
# Funds 648.1
#
# Prediction 0
# Actual 1
# Favourite 2
# Prediction proba [0.537218   0.31710252 0.14567955]
# Home, Draw and Away odds 3.6 3.6 2.0
# Funds 638.1
#
# Prediction 1
# Actual 1
# Favourite 2
# Prediction proba [0.25149193 0.38196594 0.36654216]
# Home, Draw and Away odds 2.62 3.5 2.6
# Funds 663.1
#
# Prediction 0
# Actual 2
# Favourite 0
# Prediction proba [0.42774317 0.32314888 0.24910791]
# Home, Draw and Away odds 2.05 3.6 3.5
# Funds 663.1
#
# Prediction 0
# Actual 0
# Favourite 2
# Prediction proba [0.53191286 0.3298658  0.13822141]
# Home, Draw and Away odds 2.87 3.5 2.37
# Funds 681.8000000000001
#
# Prediction 0
# Actual 0
# Favourite 0
# Prediction proba [0.5385098  0.31387427 0.147616  ]
# Home, Draw and Away odds 2.0 3.8 3.5
# Funds 691.8000000000001
#
# Prediction 2
# Actual 2
# Favourite 0
# Prediction proba [0.08438919 0.2917237  0.6238871 ]
# Home, Draw and Away odds 1.61 3.75 6.0
# Funds 741.8000000000001
#
# Prediction 0
# Actual 0
# Favourite 0
# Prediction proba [9.9963665e-01 3.4798976e-04 1.5367425e-05]
# Home, Draw and Away odds 1.1 11.0 21.0
# Funds 742.8000000000001
#
# Prediction 0
# Actual 1
# Favourite 0
# Prediction proba [0.79532254 0.129248   0.07542948]
# Home, Draw and Away odds 2.5 3.2 3.0
# Funds 732.8000000000001
#
# Prediction 2
# Actual 1
# Favourite 0
# Prediction proba [0.17435311 0.37143877 0.4542081 ]
# Home, Draw and Away odds 2.62 3.1 2.87
# Funds 722.8000000000001
#
# Prediction 0
# Actual 0
# Favourite 2
# Prediction proba [0.9235462  0.06941929 0.00703449]
# Home, Draw and Away odds 3.1 3.6 2.2
# Funds 743.8000000000001
#
# Prediction 0
# Actual 0
# Favourite 0
# Prediction proba [0.36297873 0.33933625 0.29768506]
# Home, Draw and Away odds 1.4 4.75 8.0
# Funds 743.8000000000001
#
# Prediction 1
# Actual 2
# Favourite 2
# Prediction proba [0.17912959 0.45982522 0.36104512]
# Home, Draw and Away odds 3.5 3.75 2.0
# Funds 733.8000000000001
#
# Prediction 2
# Actual 2
# Favourite 2
# Prediction proba [0.2095991  0.27351567 0.5168853 ]
# Home, Draw and Away odds 9.0 5.25 1.33
# Funds 733.8000000000001
#
# Prediction 0
# Actual 1
# Favourite 0
# Prediction proba [0.603467   0.21403559 0.18249747]
# Home, Draw and Away odds 2.3 3.4 3.1
# Funds 723.8000000000001
#
# Prediction 1
# Actual 1
# Favourite 0
# Prediction proba [0.21925628 0.44524372 0.33550003]
# Home, Draw and Away odds 2.5 3.5 2.75
# Funds 748.8000000000001
#
# Prediction 0
# Actual 0
# Favourite 0
# Prediction proba [0.958658   0.03816359 0.00317855]
# Home, Draw and Away odds 1.4 4.75 8.0
# Funds 752.8000000000001
#
# Prediction 0
# Actual 0
# Favourite 0
# Prediction proba [0.55891955 0.2814924  0.15958807]
# Home, Draw and Away odds 1.9 3.75 3.75
# Funds 761.8000000000001
#
# Prediction 0
# Actual 0
# Favourite 0
# Prediction proba [0.5983961  0.32919672 0.0724071 ]
# Home, Draw and Away odds 1.4 4.75 8.0
# Funds 761.8000000000001
#
# Prediction 0
# Actual 0
# Favourite 0
# Prediction proba [0.9149399  0.07184418 0.01321594]
# Home, Draw and Away odds 1.85 3.4 4.5
# Funds 770.3000000000001
#
# Prediction 2
# Actual 2
# Favourite 2
# Prediction proba [0.0014363  0.02916169 0.969402  ]
# Home, Draw and Away odds 10.0 5.5 1.3
# Funds 773.3000000000001
#
# Prediction 0
# Actual 0
# Favourite 0
# Prediction proba [0.96309614 0.0347876  0.00211619]
# Home, Draw and Away odds 1.5 4.0 7.5
# Funds 778.3000000000001
#
# Prediction 0
# Actual 1
# Favourite 0
# Prediction proba [0.401309   0.39281437 0.20587662]
# Home, Draw and Away odds 2.37 3.5 2.9
# Funds 778.3000000000001
#
# Prediction 2
# Actual 0
# Favourite 2
# Prediction proba [0.2124025  0.26350406 0.5240935 ]
# Home, Draw and Away odds 3.9 3.6 1.9
# Funds 778.3000000000001
#
# Prediction 0
# Actual 0
# Favourite 2
# Prediction proba [0.7971327  0.17052598 0.0323414 ]
# Home, Draw and Away odds 2.87 3.3 2.5
# Funds 797.0000000000001
#
# Prediction 0
# Actual 0
# Favourite 0
# Prediction proba [0.55830956 0.22145623 0.2202343 ]
# Home, Draw and Away odds 1.44 4.75 7.0
# Funds 797.0000000000001
#
# Prediction 2
# Actual 2
# Favourite 0
# Prediction proba [0.01332455 0.09529045 0.89138496]
# Home, Draw and Away odds 2.37 3.6 2.8
# Funds 815.0000000000001
#
# Prediction 2
# Actual 1
# Favourite 0
# Prediction proba [0.12099516 0.23717283 0.641832  ]
# Home, Draw and Away odds 2.05 3.4 3.6
# Funds 805.0000000000001
#
# Prediction 0
# Actual 2
# Favourite 0
# Prediction proba [0.82601845 0.12548497 0.04849663]
# Home, Draw and Away odds 1.95 3.6 3.8
# Funds 795.0000000000001
#
# Prediction 0
# Actual 0
# Favourite 0
# Prediction proba [0.61721975 0.1946536  0.18812658]
# Home, Draw and Away odds 1.44 4.75 7.0
# Funds 795.0000000000001
#
# Prediction 0
# Actual 2
# Favourite 0
# Prediction proba [0.60383815 0.27180424 0.12435763]
# Home, Draw and Away odds 1.12 9.0 21.0
# Funds 795.0000000000001
#
# Prediction 2
# Actual 2
# Favourite 2
# Prediction proba [0.02198775 0.06925511 0.90875715]
# Home, Draw and Away odds 4.0 3.8 1.85
# Funds 803.5000000000001
#
# Prediction 2
# Actual 0
# Favourite 2
# Prediction proba [0.3346831  0.2662237  0.39909324]
# Home, Draw and Away odds 4.5 3.5 1.85
# Funds 803.5000000000001
#
# Prediction 2
# Actual 0
# Favourite 0
# Prediction proba [0.2841124  0.25750372 0.45838392]
# Home, Draw and Away odds 1.95 3.75 3.75
# Funds 793.5000000000001
#
# Prediction 0
# Actual 0
# Favourite 0
# Prediction proba [0.90131134 0.08914313 0.00954559]
# Home, Draw and Away odds 2.35 3.4 3.0
# Funds 807.0000000000001
#
# Prediction 0
# Actual 1
# Favourite 0
# Prediction proba [0.6626774  0.25785384 0.07946875]
# Home, Draw and Away odds 1.72 4.2 4.2
# Funds 797.0000000000001
#
# Prediction 0
# Actual 0
# Favourite 0
# Prediction proba [0.8941828  0.09360201 0.01221518]
# Home, Draw and Away odds 1.3 5.5 10.0
# Funds 800.0000000000001
#
# Prediction 0
# Actual 0
# Favourite 0
# Prediction proba [0.919252   0.06578726 0.01496076]
# Home, Draw and Away odds 1.57 4.0 6.0
# Funds 805.7000000000002
#
# Prediction 0
# Actual 1
# Favourite 0
# Prediction proba [0.8133097  0.15055683 0.03613342]
# Home, Draw and Away odds 1.4 5.0 7.5
# Funds 795.7000000000002
#
# Prediction 0
# Actual 1
# Favourite 0
# Prediction proba [0.43146428 0.2699688  0.2985669 ]
# Home, Draw and Away odds 1.8 3.6 4.5
# Funds 795.7000000000002
#
# Prediction 2
# Actual 2
# Favourite 2
# Prediction proba [0.00440655 0.03395552 0.9616379 ]
# Home, Draw and Away odds 12.0 7.0 1.22
# Funds 797.9000000000002
#
# Prediction 2
# Actual 1
# Favourite 2
# Prediction proba [0.12939022 0.4019927  0.4686171 ]
# Home, Draw and Away odds 5.25 3.8 1.65
# Funds 797.9000000000002
#
# Prediction 0
# Actual 0
# Favourite 2
# Prediction proba [0.75251925 0.20709734 0.0403834 ]
# Home, Draw and Away odds 3.9 3.75 1.9
# Funds 826.9000000000002
#
# Prediction 2
# Actual 2
# Favourite 2
# Prediction proba [0.00132579 0.01148746 0.9871867 ]
# Home, Draw and Away odds 3.1 3.4 2.3
# Funds 839.9000000000002
#
# Prediction 0
# Actual 0
# Favourite 0
# Prediction proba [0.96081877 0.03608433 0.00309688]
# Home, Draw and Away odds 1.08 11.0 26.0
# Funds 840.7000000000002
#
# Prediction 0
# Actual 0
# Favourite 2
# Prediction proba [0.49017975 0.19928221 0.31053805]
# Home, Draw and Away odds 2.9 3.25 2.5
# Funds 859.7000000000002
#
# Prediction 2
# Actual 1
# Favourite 0
# Prediction proba [0.12619756 0.16435593 0.7094465 ]
# Home, Draw and Away odds 2.15 3.6 3.25
# Funds 849.7000000000002
#
# Prediction 0
# Actual 1
# Favourite 0
# Prediction proba [0.60329133 0.30901346 0.0876952 ]
# Home, Draw and Away odds 2.1 3.5 3.5
# Funds 839.7000000000002
#
# Prediction 2
# Actual 2
# Favourite 2
# Prediction proba [0.00754281 0.05466127 0.93779594]
# Home, Draw and Away odds 4.5 4.0 1.72
# Funds 846.9000000000002
#
# Prediction 2
# Actual 1
# Favourite 2
# Prediction proba [0.11560486 0.3418821  0.542513  ]
# Home, Draw and Away odds 3.0 3.1 2.55
# Funds 836.9000000000002
#
# Prediction 0
# Actual 1
# Favourite 0
# Prediction proba [0.5141747  0.31465843 0.1711668 ]
# Home, Draw and Away odds 1.45 4.75 6.5
# Funds 836.9000000000002
#
# Prediction 0
# Actual 0
# Favourite 0
# Prediction proba [0.74943155 0.19496545 0.05560296]
# Home, Draw and Away odds 1.5 4.33 6.5
# Funds 841.9000000000002
#
# Prediction 2
# Actual 2
# Favourite 2
# Prediction proba [0.12365006 0.13441135 0.7419386 ]
# Home, Draw and Away odds 4.33 4.0 1.75
# Funds 849.4000000000002
#
# Prediction 0
# Actual 0
# Favourite 2
# Prediction proba [0.6369333  0.24038702 0.12267965]
# Home, Draw and Away odds 3.25 3.6 2.15
# Funds 871.9000000000002
#
# Prediction 1
# Actual 1
# Favourite 0
# Prediction proba [0.30919385 0.40942577 0.28138041]
# Home, Draw and Away odds 1.75 3.75 4.75
# Funds 899.4000000000002
#
# Prediction 2
# Actual 2
# Favourite 2
# Prediction proba [0.26473212 0.3249181  0.41034976]
# Home, Draw and Away odds 9.0 5.0 1.33
# Funds 899.4000000000002
#
# Prediction 0
# Actual 0
# Favourite 0
# Prediction proba [0.6686652  0.2572723  0.07406241]
# Home, Draw and Away odds 1.72 4.2 4.33
# Funds 906.6000000000003
#
# Prediction 0
# Actual 0
# Favourite 0
# Prediction proba [9.9058127e-01 9.2151286e-03 2.0363627e-04]
# Home, Draw and Away odds 1.07 13.0 23.0
# Funds 907.3000000000003
#
# Prediction 0
# Actual 0
# Favourite 0
# Prediction proba [0.81435096 0.09849922 0.08714981]
# Home, Draw and Away odds 2.25 3.2 3.4
# Funds 919.8000000000003
#
# Prediction 0
# Actual 2
# Favourite 0
# Prediction proba [0.6370621  0.25435007 0.10858785]
# Home, Draw and Away odds 1.75 3.8 4.5
# Funds 909.8000000000003
#
# Prediction 2
# Actual 2
# Favourite 2
# Prediction proba [0.02138629 0.11828002 0.8603337 ]
# Home, Draw and Away odds 5.0 4.33 1.61
# Funds 915.9000000000003
#
# Prediction 2
# Actual 2
# Favourite 2
# Prediction proba [0.00557085 0.07967345 0.9147557 ]
# Home, Draw and Away odds 3.5 3.4 2.1
# Funds 926.9000000000003
#
# Prediction 1
# Actual 1
# Favourite 2
# Prediction proba [0.22978579 0.43448204 0.33573216]
# Home, Draw and Away odds 2.7 3.4 2.6
# Funds 950.9000000000003
#
# Prediction 0
# Actual 2
# Favourite 2
# Prediction proba [0.5223591 0.2547866 0.2228544]
# Home, Draw and Away odds 2.7 3.5 2.55
# Funds 940.9000000000003
#
# Prediction 0
# Actual 0
# Favourite 0
# Prediction proba [0.9454613  0.04898258 0.00555614]
# Home, Draw and Away odds 1.33 5.0 10.0
# Funds 944.2000000000003
#
# Prediction 0
# Actual 0
# Favourite 0
# Prediction proba [0.5790944  0.24030325 0.1806023 ]
# Home, Draw and Away odds 2.25 3.5 3.1
# Funds 956.7000000000003
#
# Prediction 1
# Actual 0
# Favourite 0
# Prediction proba [0.30031443 0.40869838 0.2909871 ]
# Home, Draw and Away odds 2.55 3.25 2.8
# Funds 946.7000000000003
#
# Prediction 2
# Actual 2
# Favourite 2
# Prediction proba [0.25979945 0.24389964 0.49630085]
# Home, Draw and Away odds 2.9 3.3 2.45
# Funds 961.2000000000003
#
# Prediction 0
# Actual 1
# Favourite 0
# Prediction proba [0.42506498 0.333891   0.24104403]
# Home, Draw and Away odds 1.57 4.0 6.0
# Funds 961.2000000000003
#
# Prediction 0
# Actual 0
# Favourite 0
# Prediction proba [0.9841792  0.01390478 0.00191595]
# Home, Draw and Away odds 2.0 3.75 3.5
# Funds 971.2000000000003
#
# Prediction 0
# Actual 0
# Favourite 0
# Prediction proba [0.67560714 0.19832031 0.12607254]
# Home, Draw and Away odds 1.6 3.75 6.5
# Funds 977.2000000000003
#
# Prediction 0
# Actual 0
# Favourite 0
# Prediction proba [0.57513356 0.2997269  0.12513956]
# Home, Draw and Away odds 1.9 3.5 4.2
# Funds 986.2000000000003
#
# Prediction 1
# Actual 0
# Favourite 0
# Prediction proba [0.33756316 0.43576106 0.22667575]
# Home, Draw and Away odds 2.5 3.6 2.62
# Funds 976.2000000000003
#
# Prediction 2
# Actual 2
# Favourite 2
# Prediction proba [0.25599018 0.23959292 0.5044169 ]
# Home, Draw and Away odds 4.2 4.33 1.7
# Funds 976.2000000000003
#
# Prediction 0
# Actual 1
# Favourite 0
# Prediction proba [0.7593529  0.19769394 0.04295322]
# Home, Draw and Away odds 1.45 4.75 6.5
# Funds 966.2000000000003
#
# Prediction 2
# Actual 2
# Favourite 2
# Prediction proba [0.18050882 0.376229   0.44326216]
# Home, Draw and Away odds 2.75 3.3 2.6
# Funds 982.2000000000003
#
# Prediction 2
# Actual 2
# Favourite 2
# Prediction proba [0.02474566 0.20325516 0.7719992 ]
# Home, Draw and Away odds 3.75 3.5 2.0
# Funds 992.2000000000003
#
# Prediction 2
# Actual 2
# Favourite 2
# Prediction proba [0.1515928  0.17274874 0.67565846]
# Home, Draw and Away odds 7.5 4.75 1.4
# Funds 992.2000000000003
#
# Prediction 1
# Actual 2
# Favourite 0
# Prediction proba [0.33273894 0.39569962 0.2715614 ]
# Home, Draw and Away odds 1.36 5.1 8.0
# Funds 982.2000000000003
#
# Prediction 2
# Actual 2
# Favourite 0
# Prediction proba [0.2762437 0.211408  0.5123483]
# Home, Draw and Away odds 2.3 3.4 3.1
# Funds 1003.2000000000003
#
# Prediction 0
# Actual 0
# Favourite 0
# Prediction proba [0.68415916 0.29100385 0.02483705]
# Home, Draw and Away odds 1.44 5.0 6.5
# Funds 1003.2000000000003
#
# Prediction 0
# Actual 1
# Favourite 2
# Prediction proba [0.7334008  0.14271843 0.1238807 ]
# Home, Draw and Away odds 3.5 3.4 2.1
# Funds 993.2000000000003
#
# Prediction 0
# Actual 1
# Favourite 2
# Prediction proba [0.6649709  0.20450899 0.13052018]
# Home, Draw and Away odds 3.5 3.4 2.1
# Funds 983.2000000000003
# Betted on favourite 56 times out of 128 matches.
# No bet placed 29 times
